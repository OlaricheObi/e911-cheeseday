# %%
from shapely.geometry import Point 
from shapely.geometry import LineString
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import datetime
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %% [markdown]
# # Adding all data

# %%
tornado_911 = pd.read_csv('../data/911_Phone_Calls_Tornado_030320.csv')
cadd_tornado = pd.read_csv('../data/Computer Aided Dispatch Data_Tornado Incidents 030320.csv', skiprows = 3)
derecho_911 = pd.read_csv('../data/911_Phone Calls_Derecho_050320_050420.csv')
cadd_derecho = pd.read_csv('../data/Computer Aided Dispatch Data_Derecho Incidents 050320-050420.csv', skiprows = 3)

# %% [markdown]
# # Fixing columns

# %%
tornado_911.columns = ['time', 'calltype', 'lat', 'lng', 'cell_tower_address']
derecho_911.columns = ['time', 'calltype', 'lat', 'lng', 'cell_tower_address']
cadd_tornado.columns = ['time', 'location', 'lat', 'lng', 'incident_type']
cadd_derecho.columns = ['time', 'location', 'lat', 'lng', 'incident_type']

# %%
tornado_911.time = pd.to_datetime(tornado_911.time)
derecho_911.time = pd.to_datetime(derecho_911.time)
cadd_tornado.time = pd.to_datetime(cadd_tornado.time)
cadd_derecho.time = pd.to_datetime(cadd_derecho.time)

# %%
tornado_911['geometry'] = tornado_911.apply(lambda x: Point((float(x.lng), float(x.lat))), axis=1)
derecho_911['geometry'] = derecho_911.apply(lambda x: Point((float(x.lng), float(x.lat))), axis=1)
cadd_tornado['geometry'] = cadd_tornado.apply(lambda x: Point((float(x.lng), float(x.lat))), axis=1)
cadd_derecho['geometry'] = cadd_derecho.apply(lambda x: Point((float(x.lng), float(x.lat))), axis=1)

# %%
tornado_911.head()
# Out:
#                  time   calltype        lat        lng  \
# 0 2020-03-03 00:34:00  911 Calls  36.072708 -86.665779
# 1 2020-03-03 00:36:00  911 Calls  36.159634 -86.841904
# 2 2020-03-03 00:36:00  911 Calls  36.264153 -86.708862
# 3 2020-03-03 00:36:00  911 Calls        NaN        NaN
# 4 2020-03-03 00:36:00  911 Calls  36.233467 -86.721077
#
#            cell_tower_address                              geometry
# 0  620 Richards RD - N Sector          POINT (-86.665779 36.072708)
# 1      4507D KENTUCKY AV - SE          POINT (-86.841904 36.159634)
# 2    329 THELMA ST - S Sector          POINT (-86.708862 36.264153)
# 3              526 FOUNDRY DR                       POINT (nan nan)
# 4        5007B RUSKIN AVE - N  POINT (-86.72107699999999 36.233467)

# %%
derecho_911.head()
# Out:
#                  time   calltype        lat        lng     cell_tower_address  \
# 0 2020-05-03 16:30:00  911 Calls  36.247802 -86.716847        WIRELESS CALLER
# 1 2020-05-03 16:30:00  911 Calls  36.143108 -86.800621    1161 21ST AV S - SE
# 2 2020-05-03 16:30:00  911 Calls  36.100516 -87.056329  8013 C MCCRORY LN - N
# 3 2020-05-03 16:30:00  911 Calls  36.130021 -86.927819     5758 RIVER RD - SW
# 4 2020-05-03 16:31:00  911 Calls  36.142380 -86.881882   3744B ANNEX AVE - SE
#
#                                geometry
# 0          POINT (-86.716847 36.247802)
# 1  POINT (-86.80062100000001 36.143108)
# 2  POINT (-87.05632900000001 36.100516)
# 3          POINT (-86.927819 36.130021)
# 4           POINT (-86.881882 36.14238)

# %%
cadd_tornado.head()
# Out:
#                  time                  location        lat        lng  \
# 0 2020-03-03 00:36:34   6205 COCKRILL BEND CIR   36.182002 -86.894052
# 1 2020-03-03 00:37:24  7337 COCKRILL BEND BLVD   36.175666 -86.894978
# 2 2020-03-03 00:38:17      110 TUNE AIRPORT DR   36.179299 -86.883727
# 3 2020-03-03 00:39:40          555 MARRIOTT DR   36.151108 -86.689921
# 4 2020-03-03 00:39:42  1414 COUNTY HOSPITAL RD   36.177926 -86.845934
#
#                                  incident_type  \
# 0  GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 1  GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 2       STRUCTURE FIRE COMMERCIAL   INDUSTRIAL
# 3  GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 4  GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
#
#                                geometry
# 0      POINT (-86.89405212 36.18200191)
# 1  POINT (-86.89497756999999 36.175666)
# 2       POINT (-86.8837274 36.17929946)
# 3        POINT (-86.6899214 36.1511077)
# 4      POINT (-86.84593411 36.17792604)

# %%
cadd_derecho.head()
# Out:
#                  time            location        lat        lng  \
# 0 2020-05-03 16:31:07    901 KENWICK CT W  36.046877 -86.962526
# 1 2020-05-03 16:32:18       8036 ARBOR DR  36.082491 -86.940680
# 2 2020-05-03 16:32:23   119 DUE WEST AV E  36.248029 -86.716875
# 3 2020-05-03 16:33:04  630 GALLATIN PKE S  36.256491 -86.714817
# 4 2020-05-03 16:33:52   615 W HILLWOOD DR  36.129690 -86.879834
#
#        incident_type                          geometry
# 0  ELECTRICAL HAZARD  POINT (-86.96252641 36.04687715)
# 1  ELECTRICAL HAZARD  POINT (-86.94067952 36.08249081)
# 2     NOT ALERT COPD  POINT (-86.71687484 36.24802948)
# 3     ABDOMINAL PAIN  POINT (-86.71481656 36.25649117)
# 4  ELECTRICAL HAZARD  POINT (-86.87983392 36.12968971)

# %%
damage_points = gpd.read_file('../data/damage_points.geojson')
path_polygons = gpd.read_file('../data/path_polygons.geojson')
tornado_paths = gpd.read_file('../data/tornado_paths.geojson')

# %%
damage_points.stormdate = damage_points.stormdate.apply(lambda x: datetime.datetime.fromtimestamp(x / 1e3))
damage_points.surveydate = damage_points.surveydate.apply(lambda x: datetime.datetime.fromtimestamp(x / 1e3))
tornado_paths.stormdate = tornado_paths.stormdate.apply(lambda x: datetime.datetime.fromtimestamp(x / 1e3))
tornado_paths.starttime = tornado_paths.starttime.apply(lambda x: datetime.datetime.fromtimestamp(x / 1e3))
tornado_paths.endtime = tornado_paths.endtime.apply(lambda x: datetime.datetime.fromtimestamp(x / 1e3))

# %% [markdown]
# # creating dataframe with damage_txt (type of damage) and value counts of damage

# %%
damage_points.damage_txt.value_counts().sort_index()
# Out:
# Apartments, Condos, Townhouses [3 stories or less] (ACT)                       90
# Automobile Service Building (ASB)                                               4
# Electrical Transmission Lines (ETL)                                            20
# Elementary School [Single Story; Interior or Exterior Hallways] (ES)           10
# Free-Standing Towers (FST)                                                      1
# Institutional Building [Hospital, Government or University Building] (IB)      27
# Junior or Senior High School (JHSH)                                             3
# Large, Isolated Retail Building [K-Mart, Wal-Mart] (LIRB)                       3
# Low-Rise Building [1-4 Stories] (LRB)                                          36
# Manufactured Home - Double Wide (MHDW)                                         11
# Manufactured Home - Single Wide (MHSW)                                         35
# Masonry Apartment or Motel Building (MAM)                                       5
# Metal Building System (MBS)                                                    74
# Mid-Rise Building [5-20 Stories] (MRB)                                          4
# Motel (M)                                                                       6
# One- or Two-Family Residences (FR12)                                         2850
# Other (O)                                                                       9
# Service Station Canopy (SSC)                                                    5
# Small Barns or Farm Outbuildings (SBO)                                        412
# Small Professional Building [Doctor's Office, Branch Banks] (SPB)              33
# Small Retail Building [Fast Food Restaurants] (SRB)                            39
# Strip Mall (SM)                                                                 9
# Trees: Hardwood (TH)                                                          127
# Trees: Softwood (TS)                                                          114
# Warehouse Building [Tilt-up Walls or Heavy-Timber Construction] (WHB)          40
# Name: damage_txt, dtype: int64

# %%
nash_damage = damage_points.damage_txt.value_counts()

# %%
nash_damage
# Out:
# One- or Two-Family Residences (FR12)                                         2850
# Small Barns or Farm Outbuildings (SBO)                                        412
# Trees: Hardwood (TH)                                                          127
# Trees: Softwood (TS)                                                          114
# Apartments, Condos, Townhouses [3 stories or less] (ACT)                       90
# Metal Building System (MBS)                                                    74
# Warehouse Building [Tilt-up Walls or Heavy-Timber Construction] (WHB)          40
# Small Retail Building [Fast Food Restaurants] (SRB)                            39
# Low-Rise Building [1-4 Stories] (LRB)                                          36
# Manufactured Home - Single Wide (MHSW)                                         35
# Small Professional Building [Doctor's Office, Branch Banks] (SPB)              33
# Institutional Building [Hospital, Government or University Building] (IB)      27
# Electrical Transmission Lines (ETL)                                            20
# Manufactured Home - Double Wide (MHDW)                                         11
# Elementary School [Single Story; Interior or Exterior Hallways] (ES)           10
# Other (O)                                                                       9
# Strip Mall (SM)                                                                 9
# Motel (M)                                                                       6
# Masonry Apartment or Motel Building (MAM)                                       5
# Service Station Canopy (SSC)                                                    5
# Automobile Service Building (ASB)                                               4
# Mid-Rise Building [5-20 Stories] (MRB)                                          4
# Large, Isolated Retail Building [K-Mart, Wal-Mart] (LIRB)                       3
# Junior or Senior High School (JHSH)                                             3
# Free-Standing Towers (FST)                                                      1
# Name: damage_txt, dtype: int64

# %%
nash_damage = nash_damage.to_frame()

# %%
type(nash_damage)
# Out:
# pandas.core.frame.DataFrame

# %%
nash_damage.columns
# Out:
# Index(['damage_txt'], dtype='object')

# %%
nash_damage.plot()
# Out:
# <AxesSubplot:>

# %%
nash_damage = nash_damage.reset_index()
nash_damage
# Out:
#                                                 index  damage_txt
# 0                One- or Two-Family Residences (FR12)        2850
# 1              Small Barns or Farm Outbuildings (SBO)         412
# 2                                Trees: Hardwood (TH)         127
# 3                                Trees: Softwood (TS)         114
# 4   Apartments, Condos, Townhouses [3 stories or l...          90
# 5                         Metal Building System (MBS)          74
# 6   Warehouse Building [Tilt-up Walls or Heavy-Tim...          40
# 7   Small Retail Building [Fast Food Restaurants] ...          39
# 8               Low-Rise Building [1-4 Stories] (LRB)          36
# 9              Manufactured Home - Single Wide (MHSW)          35
# 10  Small Professional Building [Doctor's Office, ...          33
# 11  Institutional Building [Hospital, Government o...          27
# 12                Electrical Transmission Lines (ETL)          20
# 13             Manufactured Home - Double Wide (MHDW)          11
# 14  Elementary School [Single Story; Interior or E...          10
# 15                                          Other (O)           9
# 16                                    Strip Mall (SM)           9
# 17                                          Motel (M)           6
# 18          Masonry Apartment or Motel Building (MAM)           5
# 19                       Service Station Canopy (SSC)           5
# 20                  Automobile Service Building (ASB)           4
# 21             Mid-Rise Building [5-20 Stories] (MRB)           4
# 22  Large, Isolated Retail Building [K-Mart, Wal-M...           3
# 23                Junior or Senior High School (JHSH)           3
# 24                         Free-Standing Towers (FST)           1

# %%
counts = nash_damage.reset_index(drop = True)

# %%
counts
# Out:
#                                                 index  damage_txt
# 0                One- or Two-Family Residences (FR12)        2850
# 1              Small Barns or Farm Outbuildings (SBO)         412
# 2                                Trees: Hardwood (TH)         127
# 3                                Trees: Softwood (TS)         114
# 4   Apartments, Condos, Townhouses [3 stories or l...          90
# 5                         Metal Building System (MBS)          74
# 6   Warehouse Building [Tilt-up Walls or Heavy-Tim...          40
# 7   Small Retail Building [Fast Food Restaurants] ...          39
# 8               Low-Rise Building [1-4 Stories] (LRB)          36
# 9              Manufactured Home - Single Wide (MHSW)          35
# 10  Small Professional Building [Doctor's Office, ...          33
# 11  Institutional Building [Hospital, Government o...          27
# 12                Electrical Transmission Lines (ETL)          20
# 13             Manufactured Home - Double Wide (MHDW)          11
# 14  Elementary School [Single Story; Interior or E...          10
# 15                                          Other (O)           9
# 16                                    Strip Mall (SM)           9
# 17                                          Motel (M)           6
# 18          Masonry Apartment or Motel Building (MAM)           5
# 19                       Service Station Canopy (SSC)           5
# 20                  Automobile Service Building (ASB)           4
# 21             Mid-Rise Building [5-20 Stories] (MRB)           4
# 22  Large, Isolated Retail Building [K-Mart, Wal-M...           3
# 23                Junior or Senior High School (JHSH)           3
# 24                         Free-Standing Towers (FST)           1

# %%
counts.columns = ['damage_type', 'count']
counts
# Out:
#                                           damage_type  count
# 0                One- or Two-Family Residences (FR12)   2850
# 1              Small Barns or Farm Outbuildings (SBO)    412
# 2                                Trees: Hardwood (TH)    127
# 3                                Trees: Softwood (TS)    114
# 4   Apartments, Condos, Townhouses [3 stories or l...     90
# 5                         Metal Building System (MBS)     74
# 6   Warehouse Building [Tilt-up Walls or Heavy-Tim...     40
# 7   Small Retail Building [Fast Food Restaurants] ...     39
# 8               Low-Rise Building [1-4 Stories] (LRB)     36
# 9              Manufactured Home - Single Wide (MHSW)     35
# 10  Small Professional Building [Doctor's Office, ...     33
# 11  Institutional Building [Hospital, Government o...     27
# 12                Electrical Transmission Lines (ETL)     20
# 13             Manufactured Home - Double Wide (MHDW)     11
# 14  Elementary School [Single Story; Interior or E...     10
# 15                                          Other (O)      9
# 16                                    Strip Mall (SM)      9
# 17                                          Motel (M)      6
# 18          Masonry Apartment or Motel Building (MAM)      5
# 19                       Service Station Canopy (SSC)      5
# 20                  Automobile Service Building (ASB)      4
# 21             Mid-Rise Building [5-20 Stories] (MRB)      4
# 22  Large, Isolated Retail Building [K-Mart, Wal-M...      3
# 23                Junior or Senior High School (JHSH)      3
# 24                         Free-Standing Towers (FST)      1

# %%
type(counts)
# Out:
# pandas.core.frame.DataFrame

# %%
counts.plot()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (10,12))
plt.barh('damage_type', 'count', data = counts, color = (0.5,0.1,0.5,0.6))

plt.xticks(rotation = 50)
plt.xlabel('count of damage')
plt.ylabel('damage type')
plt.title('instances of damage across nashville')
plt.show()

# %%
counts.columns
# Out:
# Index(['damage_type', 'count'], dtype='object')

# %%
tornado_paths.head(10)
# Out:
#    objectid                 event_id           stormdate           starttime  \
# 0    879879                Nashville 2020-03-03 00:32:00 2020-03-03 00:32:00
# 1    879077  Hwy 69 Ballpark Tornado 2020-03-03 06:04:00 2020-03-03 06:04:00
# 2    879081           Lawley Tornado 2020-03-03 06:28:00 2020-03-03 06:28:00
# 3    879877               Cookeville 2020-03-03 01:48:00 2020-03-03 01:48:00
# 4    879878                  Goffton 2020-03-03 02:05:00 2020-03-03 02:05:00
# 5    879880               Cumberland 2020-03-03 02:25:00 2020-03-03 02:25:00
# 6    888677           Buffalo Valley 2020-03-03 01:38:00 2020-03-03 01:38:00
#
#               endtime  startlat  startlon   endlat   endlon   length  ...  \
# 0 2020-03-03 01:35:00   36.1725  -86.9478  36.1532 -85.8860  60.1317  ...
# 1 2020-03-03 06:12:00   32.6846  -87.6226  32.6863 -87.5492   4.3400  ...
# 2 2020-03-03 06:38:00   32.8648  -87.0496  32.8646 -86.9432   6.2100  ...
# 3 2020-03-03 01:56:00   36.1715  -85.6628  36.1709 -85.5135   8.3900  ...
# 4 2020-03-03 02:06:00   36.1075  -85.4461  36.1068 -85.4420   0.2300  ...
# 5 2020-03-03 02:35:00   36.1399  -85.0401  36.1243 -84.8619  10.0700  ...
# 6 2020-03-03 01:42:00   36.1602  -85.8055  36.1711 -85.7479   3.3233  ...
#
#    propdamage  edit_user  edit_time created_user   created_date  \
# 0         -99       None       None      DATians  1583461561000
# 1         -99       None       None      DATians  1583353305000
# 2         -99       None       None      DATians  1583357522000
# 3      100000       None       None      DATians  1583461208000
# 4         -99       None       None      DATians  1583461360000
# 5         -99       None       None      DATians  1583534817000
# 6         -99       None       None      DATians  1586271666000
#
#   last_edited_user  last_edited_date  \
# 0       dat_editor     1618703241000
# 1          DATians     1583358165000
# 2          DATians     1583359203000
# 3          DATians     1590771008000
# 4          DATians     1590604073000
# 5          DATians     1590605084000
# 6          DATians     1598799052000
#
#                                             comments  Shape__Length  \
# 0  An historic, long-track, strong EF-3 tornado b...       1.071075
# 1                                               None       0.074159
# 2                                               Path       0.106695
# 3  An historic, violent EF-4 tornado began in wes...       0.149870
# 4  A very brief and weak EF-0 tornado touched dow...       0.004130
# 5  An EF-2 tornado touched down near the intersec...       0.179387
# 6  An EF-0 tornado touched down near the Smith/Pu...       0.058826
#
#                                             geometry
# 0  LINESTRING (-86.94783 36.17249, -86.94461 36.1...
# 1  LINESTRING (-87.62263 32.68464, -87.62182 32.6...
# 2  LINESTRING (-87.04956 32.86476, -87.04019 32.8...
# 3  LINESTRING (-85.66285 36.17151, -85.61103 36.1...
# 4  LINESTRING (-85.44610 36.10746, -85.44203 36.1...
# 5  LINESTRING (-85.04006 36.13989, -85.03400 36.1...
# 6  LINESTRING (-85.80550 36.16017, -85.79778 36.1...
#
# [7 rows x 29 columns]

# %%
geo_tornado_911
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/z7/_8_xtlt95l3gtx376fmcy0hh0000gn/T/ipykernel_59137/1347311744.py in <module>
# ----> 1 geo_tornado_911
#
# NameError: name 'geo_tornado_911' is not defined

# %%
nashville_tornado = tornado_paths.loc[tornado_paths.event_id == 'Nashville']
nashville_tornado

# %% [markdown]
# mapping the nashville tornado

# %%
style = {'fillColor': '#ff0000', 'color': 'red'}
style2 = {'fillColor': '#ff0000', 'color': 'lightgreen'}
maptest = folium.Map(location = [36.1627, -86.7816], zoom_start = 10.2)

folium.GeoJson(path_polygons).add_to(maptest)

folium.GeoJson(nashville_tornado.geometry, style_function = lambda x:style).add_to(maptest)

    
maptest
